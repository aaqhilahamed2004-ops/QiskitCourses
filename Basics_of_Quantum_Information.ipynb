# %% [markdown]
# <a href="https://colab.research.google.com/github/aaqhilahamed2004-ops/QiskitCourses/blob/main/Basics_of_Quantum_Information.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit matplotlib pylatexenc --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 54.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 3.4 MB/s eta 0:00:00
# ...

# %%
from qiskit import __version__

print(__version__)
# Out:
# 2.4.1

# %%
import numpy as np

ket0 = np.array([[1], [0]])
ket1 = np.array([[0], [1]])

# %%
print(ket0/np.sqrt(2)+ket1/np.sqrt(2))
# Out:
# [[0.70710678]
#  [0.70710678]]

# %%
M1_all_zero = np.array([[1, 1], [0, 0]])
M2_identity = np.array([[1, 0], [0, 1]])
M3_not      = np.array([[0, 1], [1, 0]])
M4_all_one  = np.array([[0, 0], [1, 1]])

# %%
print(M1_all_zero @ ket0)
# Out:
# [[1]
#  [0]]

# %%
print(M1_all_zero @ ket1)
# Out:
# [[1]
#  [0]]

# %%
print(M2_identity @ ket1)
# Out:
# [[0]
#  [1]]

# %%
print(M3_not @ ket0)
# Out:
# [[0]
#  [1]]

# %%
print(M1_all_zero @ M2_identity @ ket0)
# Out:
# [[1]
#  [0]]

# %%
from qiskit.visualization import array_to_latex
display(array_to_latex(M3_not @ ket0))
display(array_to_latex(M3_not @ M1_all_zero))
# Out:
# $$
#
# \begin{bmatrix}
# 0  \\
#  1  \\
#  \end{bmatrix}
# $$
# $$
#
# \begin{bmatrix}
# 0 & 0  \\
#  1 & 1  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.visualization import array_to_latex
display(array_to_latex(M3_not @ ket1))
display(array_to_latex(M3_not @ M4_all_one))
# Out:
# $$
#
# \begin{bmatrix}
# 1  \\
#  0  \\
#  \end{bmatrix}
# $$
# $$
#
# \begin{bmatrix}
# 1 & 1  \\
#  0 & 0  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.quantum_info import Statevector
from numpy import sqrt
u = Statevector([1/sqrt(2), 1/sqrt(2)])
v = Statevector([2/3, 1/3])
w = Statevector([(1+1.0j)/2, (1-1.0j)/2])

# %%
display(u.draw("text"))
print()
display(u.draw("latex"))
print()
display(u.draw("latex_source"))
print()
display(v.draw("latex"))
display(w.draw("latex"))
# Out:
# [0.70710678+0.j,0.70710678+0.j]
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$
# '\\frac{\\sqrt{2}}{2} |0\\rangle+\\frac{\\sqrt{2}}{2} |1\\rangle'
# $$\frac{2}{3} |0\rangle+\frac{1}{3} |1\rangle$$
# $$(\frac{1}{2} + \frac{i}{2}) |0\rangle+(\frac{1}{2} - \frac{i}{2}) |1\rangle$$

# %%
display(u.is_valid())
display(v.is_valid())
display(w.is_valid())
# Out:
# True
# False
# True

# %%
from qiskit.visualization import plot_histogram
statistics = w.sample_counts(1000)
plot_histogram(statistics)

# %%
from qiskit.quantum_info import Operator

Y = Operator([[0, -1.0j], [1.0j, 0]])
X = Operator([[0, 1], [1, 0]])
H = Operator([[1/np.sqrt(2), 1/np.sqrt(2)], [1/sqrt(2), -1/sqrt(2)]])
S = Operator([[1, 0], [0, 1.0j]])
T = Operator([[1, 0], [0, (1+1.0j)/sqrt(2)]])

# %%
display(T.draw("latex"))
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  0 & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2}  \\
#  \end{bmatrix}
# $$

# %%
v = Statevector([1, 0])
v = v.evolve(H)
display(v.draw("latex"))
v = v.evolve(T)
display(v.draw("latex"))
v = v.evolve(S)
display(v.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$
# $$\frac{\sqrt{2}}{2} |0\rangle+(\frac{1}{2} + \frac{i}{2}) |1\rangle$$
# $$\frac{\sqrt{2}}{2} |0\rangle+(- \frac{1}{2} + \frac{i}{2}) |1\rangle$$

# %%
# !pip install qiskit pylatexenc numpy matplotlib

# %%
from qiskit.visualization import plot_histogram, array_to_latex
from qiskit.quantum_info import Statevector, Operator
from numpy import sqrt
W1 = Statevector([1/sqrt(2), 1/sqrt(2)])
display(W1.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$

# %%
velcra = Operator([[0,1], [1, 0]])
hadamard = Operator([[1/sqrt(2), 1/sqrt(2)], [1/sqrt(2), -1/sqrt(2)]])
state0 = Statevector([1, 0])

state0 = state0.evolve(velcra)
display(state0.draw("latex"))
state0 = state0.evolve(hadamard)
display(state0.draw("latex"))
# Out:
# $$ |1\rangle$$
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2}}{2} |1\rangle$$

# %%
_0 = Statevector.from_label("0")
_1 = Statevector.from_label("1")
H = Operator.from_label("H")
X = Operator.from_label("X")
display((H @_0).draw("latex"))
display(((X.tensor(H)) @ (_0 ^ _1)).draw("latex"))
display((((H @ X @ H)^X) @ _1.tensor(_0)).draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$
# $$\frac{\sqrt{2}}{2} |10\rangle- \frac{\sqrt{2}}{2} |11\rangle$$
# $$- |11\rangle$$

# %%
ghz = Statevector([1, 0, 0, 0, 0, 0, 0, 1]/sqrt(2))
display(ghz.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |000\rangle+\frac{\sqrt{2}}{2} |111\rangle$$

# %%
result, state = ghz.measure([0])

print(f"Measured: {result} \nState after Measurement:")
display(state.draw("latex"))
# Out:
# Measured: 0
# State after Measurement:
# $$ |000\rangle$$

# %%
stats = W.sample_counts(1000)
plot_histogram(stats)

# %% [markdown]
# ## Ordering of Qubits in Qiskit
#
# Qiskit normally follows the little-endian order.
#
# `|most-significant-qubit⟩......|least-significant-qubit⟩`
#
# ### Statevector function
#
# `Statevector([0, 1, 2, 3, 4, 5, 6, 7])`
#
# It assigns values in this indexing order.
#
# So, for a `phi = Statevector([1, 1, 0, 0]/sqrt(2))`
# the Statevector would be:
#
# $$phi = \frac{1}{\sqrt2}|00⟩ + \frac{1}{\sqrt2} |10⟩$$
#
# ###What does `.measure()` do when given multiple indices?
#
# `.meausre()` normally gives two outputs.
#   1. `outcome` - the measured value (0 or 1 for single qubits).
#   2.`state` - the state after measurement.
#
# But when given arguments - precise arguments as to which index/indices to measure, the order of the `outcome` is as follow:
#
# for measure([2,0])
#
# it measures the 2nd indexed qubit first. shows the result down.
# then, measures the 0th indexed qubit and writes the value down, pushing the 2nd qubit value to the right.

# %%
from qiskit.visualization import plot_state_qsphere
from qiskit.quantum_info import Statevector, Operator

W = Statevector([0, 1, 1, 0, 1, 0, 0, 0]/sqrt(3))
A = Statevector([1, 0, 0, 1]/sqrt(2))
display(W.is_valid())
display(W.draw("latex"))
W = W.evolve(Z^I^T)
display(W.draw("latex"))
print()
plot_state_qsphere(W)
# Out:
# True
# $$\frac{\sqrt{3}}{3} |001\rangle+\frac{\sqrt{3}}{3} |010\rangle+\frac{\sqrt{3}}{3} |100\rangle$$
# $$(\frac{\sqrt{6}}{6} + \frac{\sqrt{6} i}{6}) |001\rangle+\frac{\sqrt{3}}{3} |010\rangle- \frac{\sqrt{3}}{3} |100\rangle$$

# %% [markdown]
# ###Note on Phase representation
# - The visualization tool only shows phase difference.
# - Global phases are not shown.
